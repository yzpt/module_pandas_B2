# %%
import pandas
import requests
# pip install requests

# %%
url = 'https://data.lillemetropole.fr/geoserver/wfs?SERVICE=WFS&REQUEST=GetFeature&VERSION=2.0.0&TYPENAMES=mel_mobilite_et_transport%3Aparking&OUTPUTFORMAT=application%2Fjson'

response = requests.get(url)
import json

data = json.loads(response.text)
# print json with identation
print(json.dumps(data, indent=4))
# Out:
# {
#     "type": "FeatureCollection",
#     "features": [
#         {
#             "type": "Feature",
#             "id": "parking.1",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     704445.415162,
#                     7059340.511054
#                 ]
#             },
#             "geometry_name": "geom",
#             "properties": {
#                 "objectid": 1,
#                 "id": "LIL0001",
#                 "nom": "R\u00e9publique ",
#                 "adresse": "Place de la R\u00e9publique",
#                 "ville": "LILLE",
#                 "code_insee": "59350",
#                 "etat": "OUVERT",
#                 "txt_aff": "120",
#                 "nbr_total": 230,
#                 "nbr_libre": 122,
#                 "dtdate": "2024-12-13T09:08:00Z",
#                 "longitude": 3.06272406077835,
#                 "latitude": 50.6310274343908
#             }
#         },
#         {
#             "type": "Feature",
#             "id": "parking.2",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     704133.963794,
#                     7059796.512165
#                 ]
#             },
#             "geometry_name": "geom",
#             "properties": {
#                 "objectid": 2,
#                 "id": "LIL0002",
#                 "nom": "Plaza",
#                 "adresse": "Rue Nationale",
#                 "ville": "LILLE",
#                 "code_insee": "59350",
#                 "etat": "OUVERT",
#                 "txt_aff": "75",
#                 "nbr_total": 323,
#                 "nbr_libre": 75,
#                 "dtdate": "2024-12-13T09:08:00Z",
#                 "longitude": 3.05833428922619,
#                 "latitude": 50.6351218557855
#             }
#         },
#         {
#             "type": "Feature",
#             "id": "parking.3",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     704764.808825,
#                     7059700.637336
#                 ]
#             },
#             "geometry_name": "geom",
#             "properties": {
#                 "objectid": 3,
#                 "id": "LIL0003",
#                 "nom": "Tanneurs",
#                 "adresse": "Rue du Molinel",
#                 "ville": "LILLE",
#                 "code_insee": "59350",
#                 "etat": "OUVERT",
#                 "txt_aff": "310",
#                 "nbr_total": 563,
#                 "nbr_libre": 312,
#                 "dtdate": "2024-12-13T09:08:00Z",
#                 "longitude": 3.06723497620713,
#                 "latitude": 50.6342569494212
#             }
#         },
#         {
#             "type": "Feature",
#             "id": "parking.4",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     705570.611236,
#                     7059392.022501
#                 ]
#             },
#             "geometry_name": "geom",
#             "properties": {
#                 "objectid": 4,
#                 "id": "LIL0004",
#                 "nom": "Grand Palais",
#                 "adresse": "Boulevard des Cit\u00e9es Unies",
#                 "ville": "LILLE",
#                 "code_insee": "59350",
#                 "etat": "OUVERT",
#                 "txt_aff": "805",
#                 "nbr_total": 1182,
#                 "nbr_libre": 809,
#                 "dtdate": "2024-12-13T09:08:00Z",
#                 "longitude": 3.07860110232319,
#                 "latitude": 50.6314806769696
#             }
#         },
#         {
#             "type": "Feature",
#             "id": "parking.5",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     705133.104323,
#                     7059765.537221
#                 ]
#             },
#             "geometry_name": "geom",
#             "properties": {
#                 "objectid": 5,
#                 "id": "LIL0005",
#                 "nom": "Lille Flandres",
#                 "adresse": "Rue de Tournai",
#                 "ville": "LILLE",
#                 "code_insee": "59350",
#                 "etat": "OUVERT",
#                 "txt_aff": "85",
#                 "nbr_total": 374,
#                 "nbr_libre": 88,
#                 "dtdate": "2024-12-13T09:08:00Z",
#                 "longitude": 3.07243273529372,
#                 "latitude": 50.6348364543564
#             }
#         },
#         {
#             "type": "Feature",
#             "id": "parking.6",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     705178.148473,
#                     7059984.744523
#                 ]
#             },
#             "geometry_name": "geom",
#             "properties": {
#                 "objectid": 6,
#                 "id": "LIL0006",
#                 "nom": "EuraLille Centre Commercial",
#                 "adresse": "164 Avenue Willy Brandt",
#                 "ville": "LILLE",
#                 "code_insee": "59350",
#                 "etat": "OUVERT",
#                 "txt_aff": "1485",
#                 "nbr_total": 2873,
#                 "nbr_libre": 1487,
#                 "dtdate": "2024-12-13T09:08:00Z",
#                 "longitude": 3.07307121098809,
#                 "latitude": 50.6368033000333
#             }
#         },
#         {
#             "type": "Feature",
#             "id": "parking.7",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     705433.663403,
#                     7060206.221051
#                 ]
#             },
#             "geometry_name": "geom",
#             "properties": {
#                 "objectid": 7,
#                 "id": "LIL0007",
#                 "nom": "Euralille Gare B",
#                 "adresse": "Boulevard de Turin",
#                 "ville": "LILLE",
#                 "code_insee": "59350",
#                 "etat": "OUVERT",
#                 "txt_aff": "65",
#                 "nbr_total": 160,
#                 "nbr_libre": 68,
#                 "dtdate": "2024-12-13T09:08:00Z",
#                 "longitude": 3.07667993130868,
#                 "latitude": 50.6387887025163
#             }
#         },
#         {
#             "type": "Feature",
#             "id": "parking.8",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     705383.28657,
#                     7060315.484318
#                 ]
#             },
#             "geometry_name": "geom",
#             "properties": {
#                 "objectid": 8,
#                 "id": "LIL0008",
#                 "nom": "Euralille Gare A",
#                 "adresse": "Avenue de Cologne",
#                 "ville": "LILLE",
#                 "code_insee": "59350",
#                 "etat": "OUVERT",
#                 "txt_aff": "480",
#                 "nbr_total": 600,
#                 "nbr_libre": 482,
#                 "dtdate": "2024-12-13T09:08:00Z",
#                 "longitude": 3.07597049669558,
#                 "latitude": 50.6397696888289
#             }
#         },
#         {
#             "type": "Feature",
#             "id": "parking.9",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     704715.680066,
#                     7060263.065181
#                 ]
#             },
#             "geometry_name": "geom",
#             "properties": {
#                 "objectid": 9,
#                 "id": "LIL0009",
#                 "nom": "Op\u00e9ra",
#                 "adresse": "Avenue Carnot",
#                 "ville": "LILLE",
#                 "code_insee": "59350",
#                 "etat": "OUVERT",
#                 "txt_aff": "190",
#                 "nbr_total": 450,
#                 "nbr_libre": 190,
#                 "dtdate": "2024-12-13T09:08:00Z",
#                 "longitude": 3.0665484219941,
#                 "latitude": 50.6393046764454
#             }
#         },
#         {
#             "type": "Feature",
#             "id": "parking.10",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     704539.814994,
#                     7060518.693572
#                 ]
#             },
#             "geometry_name": "geom",
#             "properties": {
#                 "objectid": 10,
#                 "id": "LIL0010",
#                 "nom": "Vieux Lille",
#                 "adresse": "Avenue du Peuple Belge",
#                 "ville": "LILLE",
#                 "code_insee": "59350",
#                 "etat": "OUVERT",
#                 "txt_aff": "60",
#                 "nbr_total": 246,
#                 "nbr_libre": 63,
#                 "dtdate": "2024-12-13T09:08:00Z",
#                 "longitude": 3.06406951450518,
#                 "latitude": 50.641600035859
#             }
#         },
#         {
#             "type": "Feature",
#             "id": "parking.11",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     704509.407356,
#                     7060018.44254
#                 ]
#             },
#             "geometry_name": "geom",
#             "properties": {
#                 "objectid": 11,
#                 "id": "LIL0011",
#                 "nom": "Grand Place",
#                 "adresse": "Place du G\u00e9n\u00e9ral de Gaulle",
#                 "ville": "LILLE",
#                 "code_insee": "59350",
#                 "etat": "OUVERT",
#                 "txt_aff": "15",
#                 "nbr_total": 342,
#                 "nbr_libre": 16,
#                 "dtdate": "2024-12-13T09:08:00Z",
#                 "longitude": 3.06363468818191,
#                 "latitude": 50.6371109085775
#             }
#         },
#         {
#             "type": "Feature",
#             "id": "parking.12",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     704348.519181,
#                     7059831.231334
#                 ]
#             },
#             "geometry_name": "geom",
#             "properties": {
#                 "objectid": 12,
#                 "id": "LIL0012",
#                 "nom": "Rihour- Printemps",
#                 "adresse": "Place Rihour",
#                 "ville": "LILLE",
#                 "code_insee": "59350",
#                 "etat": "OUVERT",
#                 "txt_aff": "260",
#                 "nbr_total": 300,
#                 "nbr_libre": 263,
#                 "dtdate": "2024-12-13T09:08:00Z",
#                 "longitude": 3.06136225599413,
#                 "latitude": 50.6354319747236
#             }
#         },
#         {
#             "type": "Feature",
#             "id": "parking.13",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     704610.614868,
#                     7059687.589282
#                 ]
#             },
#             "geometry_name": "geom",
#             "properties": {
#                 "objectid": 13,
#                 "id": "LIL0013",
#                 "nom": "Rues Pi\u00e9tonnes",
#                 "adresse": "6 rue de la Rivi\u00e8re",
#                 "ville": "LILLE",
#                 "code_insee": "59350",
#                 "etat": "OUVERT",
#                 "txt_aff": "185",
#                 "nbr_total": 465,
#                 "nbr_libre": 189,
#                 "dtdate": "2024-12-13T09:08:00Z",
#                 "longitude": 3.06505903475658,
#                 "latitude": 50.634141012008
#             }
#         },
#         {
#             "type": "Feature",
#             "id": "parking.14",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     704209.075199,
#                     7060039.886732
#                 ]
#             },
#             "geometry_name": "geom",
#             "properties": {
#                 "objectid": 14,
#                 "id": "LIL0014",
#                 "nom": "Nouveau Si\u00e8cle",
#                 "adresse": "19 place Mend\u00e8s France",
#                 "ville": "LILLE",
#                 "code_insee": "59350",
#                 "etat": "OUVERT",
#                 "txt_aff": "365",
#                 "nbr_total": 733,
#                 "nbr_libre": 368,
#                 "dtdate": "2024-12-13T09:08:00Z",
#                 "longitude": 3.05939676781771,
#                 "latitude": 50.63730545319
#             }
#         },
#         {
#             "type": "Feature",
#             "id": "parking.15",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     703595.804964,
#                     7060194.566273
#                 ]
#             },
#             "geometry_name": "geom",
#             "properties": {
#                 "objectid": 15,
#                 "id": "LIL0015",
#                 "nom": "Libert\u00e9",
#                 "adresse": "Fa\u00e7ade de l Esplanade",
#                 "ville": "LILLE",
#                 "code_insee": "59350",
#                 "etat": "OUVERT",
#                 "txt_aff": "510",
#                 "nbr_total": 570,
#                 "nbr_libre": 514,
#                 "dtdate": "2024-12-13T09:08:00Z",
#                 "longitude": 3.05074395147305,
#                 "latitude": 50.6386974180716
#             }
#         },
#         {
#             "type": "Feature",
#             "id": "parking.16",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     703523.791143,
#                     7060856.340549
#                 ]
#             },
#             "geometry_name": "geom",
#             "properties": {
#                 "objectid": 16,
#                 "id": "LIL0016",
#                 "nom": "Petit Paradis",
#                 "adresse": "Fa\u00e7ade Esplanade",
#                 "ville": "LILLE",
#                 "code_insee": "59350",
#                 "etat": "OUVERT",
#                 "txt_aff": "250",
#                 "nbr_total": 270,
#                 "nbr_libre": 250,
#                 "dtdate": "2024-12-13T09:08:00Z",
#                 "longitude": 3.04973357570029,
#                 "latitude": 50.6446366979549
#             }
#         },
#         {
#             "type": "Feature",
#             "id": "parking.17",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     705415.378885,
#                     7060476.381997
#                 ]
#             },
#             "geometry_name": "geom",
#             "properties": {
#                 "objectid": 17,
#                 "id": "LIL0017",
#                 "nom": "Euralille Gare C",
#                 "adresse": "Rue du Ballon",
#                 "ville": "LILLE",
#                 "code_insee": "59350",
#                 "etat": "OUVERT",
#                 "txt_aff": "525",
#                 "nbr_total": 542,
#                 "nbr_libre": 525,
#                 "dtdate": "2024-12-13T09:08:00Z",
#                 "longitude": 3.07642559013773,
#                 "latitude": 50.6412133346671
#             }
#         },
#         {
#             "type": "Feature",
#             "id": "parking.18",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     712662.625533,
#                     7065850.92254
#                 ]
#             },
#             "geometry_name": "geom",
#             "properties": {
#                 "objectid": 18,
#                 "id": "RBX0001",
#                 "nom": "Churchill",
#                 "adresse": "Rue du pr\u00e9sident Vincent Auriol",
#                 "ville": "LILLE",
#                 "code_insee": "59350",
#                 "etat": "OUVERT",
#                 "txt_aff": "435",
#                 "nbr_total": 450,
#                 "nbr_libre": 435,
#                 "dtdate": "2024-12-13T09:08:00Z",
#                 "longitude": 3.17887534423274,
#                 "latitude": 50.6893384559637
#             }
#         },
#         {
#             "type": "Feature",
#             "id": "parking.19",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     712829.186775,
#                     7066033.481831
#                 ]
#             },
#             "geometry_name": "geom",
#             "properties": {
#                 "objectid": 19,
#                 "id": "RBX0002",
#                 "nom": "Lannoy",
#                 "adresse": "Rue Charles Watteeuw",
#                 "ville": "ROUBAIX",
#                 "code_insee": "59512",
#                 "etat": "OUVERT",
#                 "txt_aff": "520",
#                 "nbr_total": 403,
#                 "nbr_libre": 719,
#                 "dtdate": "2024-12-13T09:08:00Z",
#                 "longitude": 3.18123413986201,
#                 "latitude": 50.6909732421883
#             }
#         },
#         {
#             "type": "Feature",
#             "id": "parking.20",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     712705.740841,
#                     7066030.758758
#                 ]
#             },
#             "geometry_name": "geom",
#             "properties": {
#                 "objectid": 20,
#                 "id": "RBX0003",
#                 "nom": "Gambetta",
#                 "adresse": "Rue Charles Watteeuw",
#                 "ville": "ROUBAIX",
#                 "code_insee": "59512",
#                 "etat": "OUVERT",
#                 "txt_aff": "520",
#                 "nbr_total": 800,
#                 "nbr_libre": 778,
#                 "dtdate": "2024-12-13T09:08:00Z",
#                 "longitude": 3.17949017413449,
#                 "latitude": 50.6909513370004
#             }
#         },
#         {
#             "type": "Feature",
#             "id": "parking.21",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     712459.469544,
#                     7065959.84873
#                 ]
#             },
#             "geometry_name": "geom",
#             "properties": {
#                 "objectid": 21,
#                 "id": "RBX0005",
#                 "nom": "La Poste",
#                 "adresse": "Rue de la Halle",
#                 "ville": "ROUBAIX",
#                 "code_insee": "59512",
#                 "etat": "OUVERT",
#                 "txt_aff": "70",
#                 "nbr_total": 82,
#                 "nbr_libre": 74,
#                 "dtdate": "2024-12-13T09:08:00Z",
#                 "longitude": 3.17600895247468,
#                 "latitude": 50.6903200014822
#             }
#         },
#         {
#             "type": "Feature",
#             "id": "parking.22",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     712435.479847,
#                     7066295.272235
#                 ]
#             },
#             "geometry_name": "geom",
#             "properties": {
#                 "objectid": 22,
#                 "id": "RBX0006",
#                 "nom": "Grand Rue",
#                 "adresse": "Avenue des Nations Unies",
#                 "ville": "ROUBAIX",
#                 "code_insee": "59512",
#                 "etat": "OUVERT",
#                 "txt_aff": "855",
#                 "nbr_total": 950,
#                 "nbr_libre": 855,
#                 "dtdate": "2024-12-13T09:08:00Z",
#                 "longitude": 3.17568060484885,
#                 "latitude": 50.693330393965
#             }
#         },
#         {
#             "type": "Feature",
#             "id": "parking.23",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     712184.452527,
#                     7066044.677161
#                 ]
#             },
#             "geometry_name": "geom",
#             "properties": {
#                 "objectid": 23,
#                 "id": "RBX0007",
#                 "nom": "Centre",
#                 "adresse": "Rue Neuve",
#                 "ville": "ROUBAIX",
#                 "code_insee": "59512",
#                 "etat": "OUVERT",
#                 "txt_aff": "15",
#                 "nbr_total": 85,
#                 "nbr_libre": 19,
#                 "dtdate": "2024-12-13T09:08:00Z",
#                 "longitude": 3.17212654356232,
#                 "latitude": 50.6910866485181
#             }
#         },
#         {
#             "type": "Feature",
#             "id": "parking.24",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     711239.820514,
#                     7069868.199343
#                 ]
#             },
#             "geometry_name": "geom",
#             "properties": {
#                 "objectid": 24,
#                 "id": "TCG0001",
#                 "nom": "H\u00f4tel de Ville",
#                 "adresse": "Rue de la Bienfaisance",
#                 "ville": "TOURCOING",
#                 "code_insee": "59599",
#                 "etat": "OUVERT",
#                 "txt_aff": "72",
#                 "nbr_total": 434,
#                 "nbr_libre": 72,
#                 "dtdate": "2024-12-13T09:08:00Z",
#                 "longitude": 3.15889070231369,
#                 "latitude": 50.7254138458786
#             }
#         },
#         {
#             "type": "Feature",
#             "id": "parking.25",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     711663.371543,
#                     7069548.740957
#                 ]
#             },
#             "geometry_name": "geom",
#             "properties": {
#                 "objectid": 25,
#                 "id": "TCG0002",
#                 "nom": "Miss Cavell",
#                 "adresse": "Avenue Allende",
#                 "ville": "TOURCOING",
#                 "code_insee": "59599",
#                 "etat": "OUVERT",
#                 "txt_aff": "57",
#                 "nbr_total": 273,
#                 "nbr_libre": 57,
#                 "dtdate": "2024-12-13T09:08:00Z",
#                 "longitude": 3.1648687467852,
#                 "latitude": 50.7225395410981
#             }
#         },
#         {
#             "type": "Feature",
#             "id": "parking.26",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     711062.382901,
#                     7069242.168426
#                 ]
#             },
#             "geometry_name": "geom",
#             "properties": {
#                 "objectid": 26,
#                 "id": "TCG0003",
#                 "nom": "Saint-Christophe",
#                 "adresse": "Rue des Anges",
#                 "ville": "TOURCOING",
#                 "code_insee": "59599",
#                 "etat": "OUVERT",
#                 "txt_aff": "608",
#                 "nbr_total": 757,
#                 "nbr_libre": 608,
#                 "dtdate": "2024-12-13T09:08:00Z",
#                 "longitude": 3.1563648534293,
#                 "latitude": 50.7197996106467
#             }
#         },
#         {
#             "type": "Feature",
#             "id": "parking.27",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     709812.930606,
#                     7057481.447056
#                 ]
#             },
#             "geometry_name": "geom",
#             "properties": {
#                 "objectid": 27,
#                 "id": "VAQ0001",
#                 "nom": "Triolo",
#                 "adresse": "Avenue Paul Langevin",
#                 "ville": "VILLENEUVE-D ASCQ",
#                 "code_insee": null,
#                 "etat": "FERME",
#                 "txt_aff": "FERME",
#                 "nbr_total": 1400,
#                 "nbr_libre": 0,
#                 "dtdate": "2024-12-13T09:08:00Z",
#                 "longitude": 3.13841270858515,
#                 "latitude": 50.6142820847661
#             }
#         },
#         {
#             "type": "Feature",
#             "id": "parking.28",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     709798.067171,
#                     7056405.152819
#                 ]
#             },
#             "geometry_name": "geom",
#             "properties": {
#                 "objectid": 28,
#                 "id": "VAQ0002",
#                 "nom": "4 Cantons",
#                 "adresse": "Avenue Pointcar\u00e9",
#                 "ville": "VILLENEUVE-D ASCQ",
#                 "code_insee": null,
#                 "etat": "OUVERT",
#                 "txt_aff": "975",
#                 "nbr_total": 2000,
#                 "nbr_libre": 978,
#                 "dtdate": "2024-12-13T09:08:00Z",
#                 "longitude": 3.13817649255874,
#                 "latitude": 50.6046230353352
#             }
#         },
#         {
#             "type": "Feature",
#             "id": "parking.29",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     708799.380488,
#                     7061372.376668
#                 ]
#             },
#             "geometry_name": "geom",
#             "properties": {
#                 "objectid": 29,
#                 "id": "VAQ0003",
#                 "nom": "Les Pr\u00e8s",
#                 "adresse": "Boulevard de l Ouest",
#                 "ville": "VILLENEUVE-D ASCQ",
#                 "code_insee": null,
#                 "etat": ".",
#                 "txt_aff": ".",
#                 "nbr_total": 1000,
#                 "nbr_libre": 0,
#                 "dtdate": "2024-12-13T09:08:00Z",
#                 "longitude": 3.12420279836092,
#                 "latitude": 50.6492155080087
#             }
#         }
#     ],
#     "totalFeatures": 29,
#     "numberMatched": 29,
#     "numberReturned": 29,
#     "timeStamp": "2024-12-13T08:14:41.102Z",
#     "crs": {
#         "type": "name",
#         "properties": {
#             "name": "urn:ogc:def:crs:EPSG::2154"
#         }
#     }
# }
