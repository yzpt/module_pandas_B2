# %%
import pandas as pd

# %%
df = pd.read_csv('data/structure_pop_2021.csv', sep=';')
# Out:
# /tmp/ipykernel_39469/3519034992.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/structure_pop_2021.csv', sep=';')

# %%
df
# Out:
#       CODGEO  P21_POP   P21_POP0014   P21_POP1529   P21_POP3044   P21_POP4559  \
# 0       1001    832.0    158.552045    100.025669    152.787222    198.071134
# 1       1002    267.0     57.046286     32.439093     57.272224     58.101506
# 2       1004  14854.0   2789.758194   3081.375266   2740.192625   2632.565876
# 3       1005   1897.0    367.334805    289.213773    388.963943    415.518703
# 4       1006    113.0      9.912281     13.877193     19.824561     23.789474
# ...      ...      ...           ...           ...           ...           ...
# 34958  97420  24293.0   5564.329899   4853.335481   4556.391863   5370.832301
# 34959  97421   7243.0   1700.208360   1326.662599   1298.668993   1620.251575
# 34960  97422  81943.0  18285.741483  16318.584869  15214.365223  16589.370571
# 34961  97423   6899.0   1342.305384   1253.046383   1257.043099   1694.133409
# 34962  97424   5390.0   1082.145083    844.494729    969.707026   1314.192831
#
#         P21_POP6074  P21_POP7589  P21_POP90P      P21_POPH  ...  \
# 0        149.720218    67.098389    5.745324    423.485017  ...
# 1         40.504740    19.768434    1.867717    139.890359  ...
# 2       2269.033228  1152.137702  188.937109   7125.780104  ...
# 3        301.217072   123.672440   11.079265    950.047549  ...
# 4         37.666667     7.929825    0.000000     59.473684  ...
# ...             ...          ...         ...           ...  ...
# 34958   2864.635451   997.155641   86.319364  11625.454414  ...
# 34959    896.342643   371.422147   29.443683   3708.341532  ...
# 34960  11142.902995  4009.875265  382.159595  39408.301198  ...
# 34961    950.602949   352.302838   49.565938   3415.571915  ...
# 34962    832.305572   319.769028   27.385731   2725.896370  ...
#
#        C10_POP2554_CS8    C10_POP55P  C10_POP55P_CS1  C10_POP55P_CS2  \
# 0             0.000000    225.148718        0.000000        0.000000
# 1             7.555556     68.000000        0.000000        0.000000
# 2           538.066904   3477.141561        0.000000       65.560548
# 3            28.000000    392.000000        0.000000        8.000000
# 4             8.285714     53.857143        0.000000        0.000000
# ...                ...           ...             ...             ...
# 34958      1766.767693   3344.762518       47.605272       80.059700
# 34959       890.797871   1402.271569       36.668877       20.845351
# 34960      6387.479187  13487.474902      182.702044      261.426915
# 34961       656.000000   1176.000000       20.000000       12.000000
# 34962       683.208214   1208.154707        8.540103       17.080205
#
#        C10_POP55P_CS3  C10_POP55P_CS4  C10_POP55P_CS5  C10_POP55P_CS6  \
# 0           16.082051        4.020513       20.102564       12.061538
# 1            0.000000        0.000000        0.000000        7.555556
# 2           69.417225      137.972930      136.692417      136.554034
# 3            8.000000        8.000000        8.000000       12.000000
# 4            0.000000        8.285714        8.285714        0.000000
# ...               ...             ...             ...             ...
# 34958       55.779516      107.796290      272.307630      195.626300
# 34959       12.271528       16.430611       99.187829       93.749841
# 34960      280.403428      398.194729      821.079879      445.554424
# 34961        0.000000       16.000000      136.000000       52.000000
# 34962        4.270051        4.270051       76.860924       81.130975
#
#        C10_POP55P_CS7  C10_POP55P_CS8
# 0          164.841026        8.041026
# 1           60.444444        0.000000
# 2         2673.140809      257.803598
# 3          316.000000       32.000000
# 4           37.285714        0.000000
# ...               ...             ...
# 34958     1918.451240      667.136572
# 34959      790.827932      332.289599
# 34960     8730.994732     2367.118750
# 34961      684.000000      256.000000
# 34962      657.587906      358.414491
#
# [34963 rows x 292 columns]

# %%
df.columns
# Out:
# Index(['CODGEO', 'P21_POP', 'P21_POP0014', 'P21_POP1529', 'P21_POP3044',
#        'P21_POP4559', 'P21_POP6074', 'P21_POP7589', 'P21_POP90P', 'P21_POPH',
#        ...
#        'C10_POP2554_CS8', 'C10_POP55P', 'C10_POP55P_CS1', 'C10_POP55P_CS2',
#        'C10_POP55P_CS3', 'C10_POP55P_CS4', 'C10_POP55P_CS5', 'C10_POP55P_CS6',
#        'C10_POP55P_CS7', 'C10_POP55P_CS8'],
#       dtype='object', length=292)

# %%
pd.set_option('display.max_rows', 500)

# %% [markdown]
# https://www.insee.fr/fr/statistiques/8201904?sommaire=8202287#dictionnaire

# %%
pd.DataFrame(df.columns)
# Out:
#                       0
# 0                CODGEO
# 1               P21_POP
# 2           P21_POP0014
# 3           P21_POP1529
# 4           P21_POP3044
# 5           P21_POP4559
# 6           P21_POP6074
# 7           P21_POP7589
# 8            P21_POP90P
# 9              P21_POPH
# 10            P21_H0014
# 11            P21_H1529
# 12            P21_H3044
# 13            P21_H4559
# 14            P21_H6074
# 15            P21_H7589
# 16             P21_H90P
# 17            P21_H0019
# 18            P21_H2064
# 19             P21_H65P
# 20             P21_POPF
# 21            P21_F0014
# 22            P21_F1529
# 23            P21_F3044
# 24            P21_F4559
# 25            P21_F6074
# 26            P21_F7589
# 27             P21_F90P
# 28            P21_F0019
# 29            P21_F2064
# 30             P21_F65P
# 31           P21_POP01P
# 32     P21_POP01P_IRAN1
# 33     P21_POP01P_IRAN2
# 34     P21_POP01P_IRAN3
# 35     P21_POP01P_IRAN4
# 36     P21_POP01P_IRAN5
# 37     P21_POP01P_IRAN6
# 38     P21_POP01P_IRAN7
# 39   P21_POP0114_IRAN2P
# 40    P21_POP0114_IRAN2
# 41   P21_POP0114_IRAN3P
# 42   P21_POP1524_IRAN2P
# 43    P21_POP1524_IRAN2
# 44   P21_POP1524_IRAN3P
# 45   P21_POP2554_IRAN2P
# 46    P21_POP2554_IRAN2
# 47   P21_POP2554_IRAN3P
# 48    P21_POP55P_IRAN2P
# 49     P21_POP55P_IRAN2
# 50    P21_POP55P_IRAN3P
# 51           C21_POP15P
# 52       C21_POP15P_CS1
# 53       C21_POP15P_CS2
# 54       C21_POP15P_CS3
# 55       C21_POP15P_CS4
# 56       C21_POP15P_CS5
# 57       C21_POP15P_CS6
# 58       C21_POP15P_CS7
# 59       C21_POP15P_CS8
# 60             C21_H15P
# 61         C21_H15P_CS1
# 62         C21_H15P_CS2
# 63         C21_H15P_CS3
# 64         C21_H15P_CS4
# 65         C21_H15P_CS5
# 66         C21_H15P_CS6
# 67         C21_H15P_CS7
# 68         C21_H15P_CS8
# 69             C21_F15P
# 70         C21_F15P_CS1
# 71         C21_F15P_CS2
# 72         C21_F15P_CS3
# 73         C21_F15P_CS4
# 74         C21_F15P_CS5
# 75         C21_F15P_CS6
# 76         C21_F15P_CS7
# 77         C21_F15P_CS8
# 78          C21_POP1524
# 79      C21_POP1524_CS1
# 80      C21_POP1524_CS2
# 81      C21_POP1524_CS3
# 82      C21_POP1524_CS4
# 83      C21_POP1524_CS5
# 84      C21_POP1524_CS6
# 85      C21_POP1524_CS7
# 86      C21_POP1524_CS8
# 87          C21_POP2554
# 88      C21_POP2554_CS1
# 89      C21_POP2554_CS2
# 90      C21_POP2554_CS3
# 91      C21_POP2554_CS4
# 92      C21_POP2554_CS5
# 93      C21_POP2554_CS6
# 94      C21_POP2554_CS7
# 95      C21_POP2554_CS8
# 96           C21_POP55P
# 97       C21_POP55P_CS1
# 98       C21_POP55P_CS2
# 99       C21_POP55P_CS3
# 100      C21_POP55P_CS4
# 101      C21_POP55P_CS5
# 102      C21_POP55P_CS6
# 103      C21_POP55P_CS7
# 104      C21_POP55P_CS8
# 105             P15_POP
# 106         P15_POP0014
# 107         P15_POP1529
# 108         P15_POP3044
# 109         P15_POP4559
# 110         P15_POP6074
# 111         P15_POP7589
# 112          P15_POP90P
# 113            P15_POPH
# 114           P15_H0014
# 115           P15_H1529
# 116           P15_H3044
# 117           P15_H4559
# 118           P15_H6074
# 119           P15_H7589
# 120            P15_H90P
# 121           P15_H0019
# 122           P15_H2064
# 123            P15_H65P
# 124            P15_POPF
# 125           P15_F0014
# 126           P15_F1529
# 127           P15_F3044
# 128           P15_F4559
# 129           P15_F6074
# 130           P15_F7589
# 131            P15_F90P
# 132           P15_F0019
# 133           P15_F2064
# 134            P15_F65P
# 135          P15_POP01P
# 136    P15_POP01P_IRAN1
# 137    P15_POP01P_IRAN2
# 138    P15_POP01P_IRAN3
# 139    P15_POP01P_IRAN4
# 140    P15_POP01P_IRAN5
# 141    P15_POP01P_IRAN6
# 142    P15_POP01P_IRAN7
# 143  P15_POP0114_IRAN2P
# 144   P15_POP0114_IRAN2
# 145  P15_POP0114_IRAN3P
# 146  P15_POP1524_IRAN2P
# 147   P15_POP1524_IRAN2
# 148  P15_POP1524_IRAN3P
# 149  P15_POP2554_IRAN2P
# 150   P15_POP2554_IRAN2
# 151  P15_POP2554_IRAN3P
# 152   P15_POP55P_IRAN2P
# 153    P15_POP55P_IRAN2
# 154   P15_POP55P_IRAN3P
# 155          C15_POP15P
# 156      C15_POP15P_CS1
# 157      C15_POP15P_CS2
# 158      C15_POP15P_CS3
# 159      C15_POP15P_CS4
# 160      C15_POP15P_CS5
# 161      C15_POP15P_CS6
# 162      C15_POP15P_CS7
# 163      C15_POP15P_CS8
# 164            C15_H15P
# 165        C15_H15P_CS1
# 166        C15_H15P_CS2
# 167        C15_H15P_CS3
# 168        C15_H15P_CS4
# 169        C15_H15P_CS5
# 170        C15_H15P_CS6
# 171        C15_H15P_CS7
# 172        C15_H15P_CS8
# 173            C15_F15P
# 174        C15_F15P_CS1
# 175        C15_F15P_CS2
# 176        C15_F15P_CS3
# 177        C15_F15P_CS4
# 178        C15_F15P_CS5
# 179        C15_F15P_CS6
# 180        C15_F15P_CS7
# 181        C15_F15P_CS8
# 182         C15_POP1524
# 183     C15_POP1524_CS1
# 184     C15_POP1524_CS2
# 185     C15_POP1524_CS3
# 186     C15_POP1524_CS4
# 187     C15_POP1524_CS5
# 188     C15_POP1524_CS6
# 189     C15_POP1524_CS7
# 190     C15_POP1524_CS8
# 191         C15_POP2554
# 192     C15_POP2554_CS1
# 193     C15_POP2554_CS2
# 194     C15_POP2554_CS3
# 195     C15_POP2554_CS4
# 196     C15_POP2554_CS5
# 197     C15_POP2554_CS6
# 198     C15_POP2554_CS7
# 199     C15_POP2554_CS8
# 200          C15_POP55P
# 201      C15_POP55P_CS1
# 202      C15_POP55P_CS2
# 203      C15_POP55P_CS3
# 204      C15_POP55P_CS4
# 205      C15_POP55P_CS5
# 206      C15_POP55P_CS6
# 207      C15_POP55P_CS7
# 208      C15_POP55P_CS8
# 209             P10_POP
# 210         P10_POP0014
# 211         P10_POP1529
# 212         P10_POP3044
# 213         P10_POP4559
# 214         P10_POP6074
# 215          P10_POP75P
# 216            P10_POPH
# 217           P10_H0014
# 218           P10_H1529
# 219           P10_H3044
# 220           P10_H4559
# 221           P10_H6074
# 222           P10_H7589
# 223            P10_H90P
# 224           P10_H0019
# 225           P10_H2064
# 226            P10_H65P
# 227            P10_POPF
# 228           P10_F0014
# 229           P10_F1529
# 230           P10_F3044
# 231           P10_F4559
# 232           P10_F6074
# 233           P10_F7589
# 234            P10_F90P
# 235           P10_F0019
# 236           P10_F2064
# 237            P10_F65P
# 238          C10_POP15P
# 239      C10_POP15P_CS1
# 240      C10_POP15P_CS2
# 241      C10_POP15P_CS3
# 242      C10_POP15P_CS4
# 243      C10_POP15P_CS5
# 244      C10_POP15P_CS6
# 245      C10_POP15P_CS7
# 246      C10_POP15P_CS8
# 247            C10_H15P
# 248        C10_H15P_CS1
# 249        C10_H15P_CS2
# 250        C10_H15P_CS3
# 251        C10_H15P_CS4
# 252        C10_H15P_CS5
# 253        C10_H15P_CS6
# 254        C10_H15P_CS7
# 255        C10_H15P_CS8
# 256            C10_F15P
# 257        C10_F15P_CS1
# 258        C10_F15P_CS2
# 259        C10_F15P_CS3
# 260        C10_F15P_CS4
# 261        C10_F15P_CS5
# 262        C10_F15P_CS6
# 263        C10_F15P_CS7
# 264        C10_F15P_CS8
# 265         C10_POP1524
# 266     C10_POP1524_CS1
# 267     C10_POP1524_CS2
# 268     C10_POP1524_CS3
# 269     C10_POP1524_CS4
# 270     C10_POP1524_CS5
# 271     C10_POP1524_CS6
# 272     C10_POP1524_CS7
# 273     C10_POP1524_CS8
# 274         C10_POP2554
# 275     C10_POP2554_CS1
# 276     C10_POP2554_CS2
# 277     C10_POP2554_CS3
# 278     C10_POP2554_CS4
# 279     C10_POP2554_CS5
# 280     C10_POP2554_CS6
# 281     C10_POP2554_CS7
# 282     C10_POP2554_CS8
# 283          C10_POP55P
# 284      C10_POP55P_CS1
# 285      C10_POP55P_CS2
# 286      C10_POP55P_CS3
# 287      C10_POP55P_CS4
# 288      C10_POP55P_CS5
# 289      C10_POP55P_CS6
# 290      C10_POP55P_CS7
# 291      C10_POP55P_CS8

# %%
# Colonnes d'intérêt :

# CODGEO : Code géographique de la commune
# P21_POP : population en 2021
# P21_POP0014 : Nombre de personnes de 0 à 14 ans en 2021
# P21_POP1529 : Nombre de personnes de 15 à 29 ans en 2021
# P21_POP3044 : Nombre de personnes de 30 à 44 ans en 2021
# P21_POP4559 : Nombre de personnes de 45 à 59 ans en 2021
# P21_POP6074 : Nombre de personnes de 60 à 74 ans en 2021
# P21_POP7589 : Nombre de personnes de 75 à 89 ans en 2021
# P21_POP90P : Nombre de personnes de 90 ans ou plus en 2021

df = df[['CODGEO', 'P21_POP', 'P21_POP0014', 'P21_POP1529', 'P21_POP3044', 'P21_POP4559', 'P21_POP6074', 'P21_POP7589', 'P21_POP90P']]
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 13
#       1 # Colonnes d'intérêt :
#       2
#       3 # CODGEO : Code géographique de la commune
#    (...)
#      10 # P21_POP7589 : Nombre de personnes de 75 à 89 ans en 2021
#      11 # P21_POP90P : Nombre de personnes de 90 ans ou plus en 2021
# ---> 13 df = df[['CODGEO', 'P21_POP', 'P21_POP0014', 'P21_POP1529', 'P21_POP3044', 'P21_POP4559', 'P21_POP6074', 'P21_POP7589', 'P21_POP90P']]
#      14 df
#
# File ~/projects/cours_pandas_B2/venv_cours_pandas/lib/python3.10/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~/projects/cours_pandas_B2/venv_cours_pandas/lib/python3.10/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~/projects/cours_pandas_B2/venv_cours_pandas/lib/python3.10/site-packages/pandas/core/indexes/base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['P21_POP'] not in index"

# %%
df[['P21_POP0014', 'P21_POP1529', 'P21_POP3044', 'P21_POP4559', 'P21_POP6074', 'P21_POP7589', 'P21_POP90P']].corr()
# Out:
#              P21_POP0014  P21_POP1529  P21_POP3044  P21_POP4559  P21_POP6074  \
# P21_POP0014     1.000000     0.963591     0.978237     0.982804     0.974348
# P21_POP1529     0.963591     1.000000     0.987470     0.974482     0.963799
# P21_POP3044     0.978237     0.987470     1.000000     0.993934     0.983286
# P21_POP4559     0.982804     0.974482     0.993934     1.000000     0.995369
# P21_POP6074     0.974348     0.963799     0.983286     0.995369     1.000000
# P21_POP7589     0.964277     0.952504     0.968854     0.984127     0.994453
# P21_POP90P      0.952514     0.951533     0.959621     0.971982     0.982939
#
#              P21_POP7589  P21_POP90P
# P21_POP0014     0.964277    0.952514
# P21_POP1529     0.952504    0.951533
# P21_POP3044     0.968854    0.959621
# P21_POP4559     0.984127    0.971982
# P21_POP6074     0.994453    0.982939
# P21_POP7589     1.000000    0.993467
# P21_POP90P      0.993467    1.000000
